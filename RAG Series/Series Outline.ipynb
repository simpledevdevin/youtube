-- %% [markdown]
-- # RAG Series Outline

-- %% [markdown]
-- ### Part 1(optional) - what is a vector search in index in databricks

-- %% [markdown]
-- ### Part 2 - Setting Up A vector Search Index in Databricks

-- %% [markdown]
-- 1. Create demo_product_texts table using [Vector Search Table Setup](https://dbc-2dc788ae-6972.cloud.databricks.com/editor/notebooks/2259485732881463?o=1295421369927567) notebook.
-- 2. Create Vector Search Index on demo_product_texts table
-- 3. Run example query against vector search index using similarity matching

-- %% [markdown]
-- ### Part 3 - Adding RAG to your vector search index

-- %% [markdown]
-- 1. Setup RAG with LLM using [RAG Setup](https://dbc-2dc788ae-6972.cloud.databricks.com/editor/notebooks/3088585788586894?o=1295421369927567) notebook
-- 2. Show a few examples

-- %% [markdown]
-- ### Part 4 - Add RAG to a Databricks App

-- %% [markdown]
-- 1. Create Databricks App
-- 2. Add code to databricks app
-- 3. Run some examples queries
