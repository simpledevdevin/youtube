# %% [markdown]
# # Agenda: AI SQL Functions
#
# ---
#
# ### 1. Overview
# Explain the goal: reading data from PDFs and turning that information into **structured table data**.
#
# **Example fields to extract:**
# - Name, email, phone number
# - Job title, years of experience
# - Other document-specific attributes
#
# ---
#
# ### 2. AI SQL Functions
# Introduce the concept, show the documentation, and explain how they fit in.
#
# | Topic | Documentation |
# |-------|---------------|
# | AI Functions (overview) | [AI Functions — Databricks](https://docs.databricks.com/aws/en/large-language-models/ai-functions) |
# | `ai_parse_document` | [ai_parse_document](https://docs.databricks.com/aws/en/sql/language-manual/functions/ai_parse_document) |
# | `ai_query` | [ai_query](https://docs.databricks.com/aws/en/sql/language-manual/functions/ai_query) |
# | `parse_json` | [parse_json](https://docs.databricks.com/aws/en/sql/language-manual/functions/parse_json) |
#
# ---
#
# ### 3. Walkthrough & Demo
# Step through the code and run a live demo.
