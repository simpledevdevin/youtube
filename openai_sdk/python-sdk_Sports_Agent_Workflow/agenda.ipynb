# %% [markdown]
# # Agenda
#
# *Sports Agent Workflow — Session Outline*

# %% [markdown]
# ---
#
# ### 1. Introduce the OpenAI SDK
#
# - Walk through the official documentation and library home.
# - **Links:**
#   - [OpenAI Python SDK (GitHub)](https://github.com/openai/openai-python)
#   - [OpenAI Libraries — Platform Docs](https://platform.openai.com/docs/libraries)
#
# ---
#
# ### 2. Explain the scenario
#
# - Build an **agentic workflow** that:
#   1. Generates a hot take from a chosen scenario.
#   2. Improves that hot take with clearer reasoning and structure.
#
# ---
#
# ### 3. Pre-requisites
#
# - An LLM API token from any supported provider (e.g. OpenAI, Gemini, Claude, Deepseek).
#
# ---
#
# ### 4. Show where to save the API token
#
# - Where and how to store the token (e.g. `.env`) so the notebook can use it securely.
#
# ---
#
# ### 5. Run through the code
#
# - Execute the workflow step by step and discuss how the SDK is used in practice.
#
# ---
#
# ### 6. Show the logs
#
# - Go to openai and show the logs
#
# ---
