# %% [markdown]
# # Read Data

# %% [markdown]
# ### Goal:
# Read a databricks table into a databricks app and display it using streamlit
#
# 1. Create app using 'hello world' template
# 2. Configure your app to use a SQL Warehouse
# 3. Give your app service principal permission to read and write the table
# 4. Discuss the code used to read the table
# 5. Design the app

# %% [markdown]
# # Write Data

# %% [markdown]
# ### Goal:
# Write to a databricks table using a databricks app.
#
# 1. Create app using 'hello world' template
# 2. Configure your app to use a SQL Warehouse
# 3. Give your app service principal permission to read and write the table
# 4. Discuss the code used to write to the table
# 5. Show a demo of table being written to
