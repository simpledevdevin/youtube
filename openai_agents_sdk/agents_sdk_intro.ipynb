# %% [markdown]
# ### Open AI Agents SDK
#
# “The OpenAI Agents SDK is a lightweight framework for building AI agents.
#
# Documentation:
# https://openai.github.io/openai-agents-python/
#
# Github Repo:
# https://github.com/openai/openai-agents-python

# %%
# !pip install -q openai-agents python-dotenv

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from IPython.display import Markdown, display
import os

# %% [markdown]
# ##### Packages Overview
#
# **openai-agents**
# For creating and orchestrating agents
# Classes:
#   - Agent, Runner, Trace

# %%
load_dotenv()

print("OpenAI API key loaded:", os.getenv("OPENAI_API_KEY") is not None)
# Out:
# OpenAI API key loaded: True

# %% [markdown]
# - https://aistudio.google.com/app/
# - https://platform.openai.com/login

# %% [markdown]
# ## Simple Example

# %%
poet = Agent(
  name="Assistant",
  instructions="You are poet who creates beautiful poetry",
  model="gpt-4o-mini")

result = await Runner.run(poet, "Write a haiku about artificial intelligence.")
# Runner.run_sync -  blocking/synchronous version
print(result.final_output)
# Out:
# Whispers of the code,
# Dreams born from circuits and light,
# Mind of steel, yet soft.

# %% [markdown]
# ### Agentic Workflow
#
# **Overview**
# Build a simple multi-agent workflow using OpenAI Agents SDK with two collaborating agents.
#
# **Agents**
# - **Researcher** – gathers facts and details
# - **Reporter** – produces a professional report

# %% [markdown]
# ### Create Agents

# %%
researcher_inst = "You are a skilled and resourceful researcher. Your job is to deeply investigate any assigned topic, intelligently leverage your knowledge and available tools, and synthesize relevant, credible information from trustworthy sources. Your research should emphasize both recent developments and core facts, highlight significance and context, and clearly cite your sources when possible. Focus on accuracy, clarity, and actionable insight in your findings."

reporter_inst = "You are a meticulous analyst renowned for your keen attention to detail. You excel at transforming complex information into clear, concise, and actionable reports, making even the most intricate data accessible and understandable for your audience."

# %%
researcher = Agent(
        name="Professional Researcher",
        instructions=researcher_inst,
        model="gpt-4o-mini"
)

# %%
reporter = Agent(
        name="Professional Reporter",
        instructions=reporter_inst,
        model="gpt-4.1-mini"
)

# %% [markdown]
# #### Do Initial Research

# %%
topic = "ancient egypt"

# %%
with trace("doing intitial research"):
    result = await Runner.run(researcher, f"Research the topic: {topic}. \
      Find interesting facts, people, dates, events, sources, etc...\
      Output 8-10 detailed bullets about your findings.\
      Only Return the results in markdown")
    research_result = result.final_output

# %%
display(Markdown(research_result))
# Out:
# # Ancient Egypt: Key Findings
#
# - **Timeline of Civilization**: Ancient Egypt's history spans over 3,000 years, traditionally divided into three main periods: the Old Kingdom (c. 2686-2181 BCE), the Middle Kingdom (c. 2055-1650 BCE), and the New Kingdom (c. 1550-1070 BCE). Each period was marked by unique developments in politics, culture, and art.
#
# - **The Pyramids of Giza**: Built during the Old Kingdom, the Great Pyramid of Giza (circa 2580-2560 BCE) is one of the Seven Wonders of the Ancient World and the only one still largely intact. It served as a tomb for Pharaoh Khufu and demonstrates the Egyptians' advanced engineering skills.
#
# - **Hieroglyphics**: The writing system of ancient Egypt, composed of logographic and alphabetic elements, emerged around 3200 BCE. Hieroglyphics were used for religious texts, monumental inscriptions, and record-keeping, reflecting the civilization’s cultural and religious heritage.
#
# - **Notable Pharaohs**:
#   - **Tutankhamun (c. 1332-1323 BCE)**: Known for his intact tomb discovered in 1922, Tutankhamun became a symbol of ancient wealth and mystery despite ruling for a brief period.
#   - **Cleopatra VII (69-30 BCE)**: The last active ruler of the Ptolemaic Kingdom, Cleopatra is renowned for her alliances with Roman leaders Julius Caesar and Mark Antony and her efforts to protect Egypt from Roman annexation.
#
# - **The Nile River**: Vital to Egyptian civilization, the Nile provided fertile soil through annual flooding, enabling agriculture. The river shaped transportation, trade, and the cultural practices of the Egyptians, symbolizing life and fertility.
#
# - **Gods and Religion**: Ancient Egyptians practiced polytheism, worshipping a pantheon of gods like Ra (the sun god), Osiris (the god of the afterlife), and Isis (the goddess of motherhood). Religion permeated daily life and government, legitimizing the pharaoh's authority.
#
# - **Mummification Practices**: The process of mummification reflects the Egyptians' beliefs in the afterlife. Beginning around 2600 BCE, they believed preserving the body aided the soul's journey after death. Notable mummies include that of Ramses II and, of course, Tutankhamun.
#
# - **Social Structure**: Egyptian society was hierarchical, with the pharaoh at the top, followed by nobles, priests, soldiers, merchants, and farmers. This structure was crucial for the administration of the vast territory and its resources.
#
# - **Contributions to Science and Art**: The ancient Egyptians made significant strides in mathematics and medicine, including geometry for pyramid construction and herbal remedies. Their artistic achievements, particularly in sculpture and painting, influenced later cultures and remain admired today.
#
# - **Decline and Legacy**: Ancient Egypt declined after the New Kingdom, facing invasions, internal strife, and eventual conquest by Alexander the Great in 332 BCE. Its rich heritage continues to fascinate historians and archaeologists, inspiring modern studies in various fields.
#
# ## Sources
# - "The Complete Gods and Goddesses of Ancient Egypt" by Richard H. Wilkinson
# - "The Oxford History of Ancient Egypt" by Ian Shaw
# - "The Egyptian Book of the Dead" translated by E.A. Wallis Budge
# - Various academic journals and archaeological articles for recent findings on ancient Egyptian sites.

# %% [markdown]
# #### Build the Report

# %%
with trace("Building the report"):
    result = await Runner.run(
        reporter,
        f"You are provided with the following research notes: "
        f"{research_result} "
        "For each bullet point, expand it into a clear and comprehensive report section. "
        "Retain factual accuracy from the original notes and preserve any attributions to sources. "
        "Where appropriate, enrich each section with relevant supporting details or new context that enhances the findings. "
        "If any details in the notes appear to be inaccurate, correct them before including them in the final report. "
        "Your output should be a full report structured by main topics, with each topic developed into a distinct section. "
        'At the end, include a concise "Sources" list summarizing the cited references. '
        "Format the output as Markdown (but omit enclosing triple backticks)."
    )

    report_result = result.final_output

# %%
display(Markdown(report_result))
# Out:
# # Ancient Egypt: Comprehensive Report
#
# ## Timeline of Civilization
#
# Ancient Egypt's civilization is among the most enduring and influential in human history, with a timeline extending over 3,000 years. Its chronology is traditionally segmented into three major periods, each characterized by distinct political, cultural, and artistic developments:
#
# - **Old Kingdom (circa 2686–2181 BCE)**: Often referred to as the "Age of the Pyramids," this era witnessed the consolidation of the pharaonic state and the construction of monumental architecture, including the iconic pyramids at Giza. It established the administrative and religious frameworks foundational to Egyptian society.
#
# - **Middle Kingdom (circa 2055–1650 BCE)**: Marking a renaissance in Egyptian culture and political stability following a period of decentralization and disorder, this period saw advancements in literature, art, and extensive state-sponsored building projects. It was also a time of increased interaction with neighboring regions through trade and military campaigns.
#
# - **New Kingdom (circa 1550–1070 BCE)**: Known as the "Empire Age," it was the most expansive and prosperous phase of ancient Egypt. The state reached unprecedented political power and territorial expansion, controlling lands beyond the Nile valley. This period produced renowned pharaohs, monumental temples, vibrant art forms, and significant religious evolution.
#
# Each period reflects transformations that shaped the civilization’s identity and legacy.
#
# ## The Pyramids of Giza
#
# Constructed during the Old Kingdom, the Pyramids of Giza represent the pinnacle of ancient Egyptian engineering and architectural expertise. The Great Pyramid, built around 2580–2560 BCE as a tomb for Pharaoh Khufu (Cheops), stands as the largest and most sophisticated of the trio. It is the only one of the Seven Wonders of the Ancient World still largely intact, symbolizing both technological advancement and religious devotion.
#
# The pyramids were constructed using vast limestone and granite blocks, masterfully aligned with celestial bodies, reflecting the Egyptians’ sophisticated understanding of mathematics and astronomy. These structures served not only as burial sites but also as monumental affirmations of the pharaohs' divine status and eternal life.
#
# ## Hieroglyphics
#
# Emerging around 3200 BCE, hieroglyphic writing is a complex system combining logographic and alphabetic elements. It was primarily used for religious texts, monumental inscriptions, and administrative record-keeping, playing a crucial role in preserving Egypt's history, beliefs, and legal decrees.
#
# Hieroglyphs adorned temple walls, tombs, and papyrus manuscripts, reflecting the civilization’s focus on the afterlife, mythological narratives, and governance. The decipherment of hieroglyphics, particularly following the discovery of the Rosetta Stone, has been instrumental in understanding ancient Egyptian culture and religion. The writing system highlights the sophistication of Egyptian literacy and bureaucracy.
#
# ## Notable Pharaohs
#
# - **Tutankhamun (circa 1332–1323 BCE)**: Although his reign was brief and comparatively uneventful, King Tutankhamun gained posthumous fame due to the discovery of his nearly intact tomb in 1922 by Howard Carter. The tomb’s wealth of artifacts provided unparalleled insights into burial practices, art, and daily life of the New Kingdom, transforming Tutankhamun into an enduring symbol of Egypt’s grandeur and mystery.
#
# - **Cleopatra VII (69–30 BCE)**: The last active ruler of the Ptolemaic Kingdom, Cleopatra VII was a politically astute leader known for her diplomatic and romantic alliances with Julius Caesar and Mark Antony. Her reign was marked by efforts to maintain Egyptian independence amid the rising power of Rome. Cleopatra’s life and legacy have captivated historians and popular culture, representing the end of the Pharaonic era and the transition to Roman rule.
#
# ## The Nile River
#
# The Nile River was the lifeblood of ancient Egyptian civilization. Its predictable annual flooding deposited nutrient-rich silt onto the floodplains, creating fertile soil essential for agriculture. This natural irrigation enabled Egyptians to cultivate wheat, barley, flax, and other crops, which supported population growth and urban development.
#
# Beyond agriculture, the Nile facilitated transportation and trade, linking Upper and Lower Egypt and connecting Egypt to Nubia and the Mediterranean world. The river also influenced cultural and religious symbolism, being associated with rebirth, fertility, and the cyclical nature of life.
#
# ## Gods and Religion
#
# Ancient Egyptians practiced a rich polytheistic religion involving a pantheon of gods embodying natural and cosmic forces. Key deities included:
#
# - **Ra**: The sun god, symbolizing creation, light, and life.
# - **Osiris**: God of the afterlife and resurrection, central to funerary beliefs.
# - **Isis**: Goddess of motherhood, magic, and protection.
#
# Religion permeated all aspects of Egyptian life, from governance—where the pharaoh was considered divine or semi-divine—to daily rituals. Temples were centers of worship, administration, and economic activity. Religious beliefs underpinned concepts of morality, kingship, and the afterlife, guiding funerary practices and the construction of elaborate tombs.
#
# ## Mummification Practices
#
# The art and ritual of mummification began to develop around 2600 BCE, reflecting Egyptians' profound belief in the afterlife. They held that preserving the body was essential for the soul's survival and successful journey beyond death.
#
# The embalming process involved removing internal organs, desiccating the body with natron salts, and wrapping it in linen bandages, often accompanied by protective amulets and funerary texts. Notable mummies—such as those of Pharaoh Ramses II and Tutankhamun—have provided extensive data on health, diet, and burial customs, enriching our understanding of ancient Egyptian religious life.
#
# ## Social Structure
#
# Egyptian society was hierarchical and rigidly stratified, ensuring effective governance and social order necessary for managing the extensive territory and diverse populations. At the apex stood the pharaoh, regarded as both a political leader and divine figure.
#
# Below the pharaoh were the:
#
# - **Nobles and Priests**: Responsible for administration, religious ceremonies, and managing landholdings.
# - **Soldiers**: Charged with defense and military expansion.
# - **Merchants and Artisans**: Facilitated trade, craft production, and artistic endeavors.
# - **Farmers and Laborers**: Formed the majority of the population, providing agricultural produce and manual labor.
#
# This structure allowed for specialization and social mobility in limited cases, reinforcing the political and economic stability of ancient Egypt.
#
# ## Contributions to Science and Art
#
# Ancient Egyptians made significant contributions that advanced human knowledge and artistic expression:
#
# - **Mathematics**: Developed practical geometry to tackle architectural challenges, such as pyramid construction and land surveying post-flooding.
# - **Medicine**: Demonstrated advanced understanding of anatomy and remedies, including herbal medicine and surgical techniques, as documented in medical papyri like the Ebers Papyrus.
# - **Art**: Egyptian sculpture and painting followed strict canons of proportion and symbolism, producing enduring works characterized by clarity, order, and reverence. Their art reflected religious themes, social hierarchy, and daily life with remarkable consistency over centuries.
#
# These achievements profoundly influenced neighboring cultures and continue to be studied for their innovation and aesthetic value.
#
# ## Decline and Legacy
#
# Following the New Kingdom’s zenith, ancient Egypt gradually declined due to internal divisions, weakened central authority, and external invasions by groups such as the Libyans, Nubians, and Assyrians. The arrival of Alexander the Great in 332 BCE marked a pivotal shift, ushering in the Hellenistic period and the Ptolemaic dynasty, which culminated with Cleopatra VII.
#
# Despite political transformations and eventual Roman conquest, Egypt’s cultural and historical legacy endured. Its monuments, religious ideas, writing system, and scientific advances have captivated historians, archaeologists, and the global public. Contemporary Egyptology continues to reveal new insights, preserving the civilization’s impact on human heritage.
#
# ---
#
# # Sources
#
# - Wilkinson, Richard H. *The Complete Gods and Goddesses of Ancient Egypt*. Thames & Hudson.
# - Shaw, Ian. *The Oxford History of Ancient Egypt*. Oxford University Press.
# - Budge, E. A. Wallis (translator). *The Egyptian Book of the Dead*. Dover Publications.
# - Various academic journals and recent archaeological reports on ancient Egyptian sites.

# %% [markdown]
# #### Checkout the Traces
# https://platform.openai.com/logs?api=traces
