# %% [markdown]
# ### Install and Import Dependencies

# %%
# %pip install -q python-dotenv litellm
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\dbenn\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os
from litellm import completion
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from dotenv import load_dotenv
#       2 import os
# ----> 3 from litellm import completion
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\litellm\__init__.py:552
#     549 #############################################
#     550 from litellm.litellm_core_utils.get_model_cost_map import get_model_cost_map
# --> 552 model_cost = get_model_cost_map(url=model_cost_map_url)
#     553 cost_discount_config: Dict[str, float] = (
#     554     {}
#     555 )  # Provider-specific cost discounts {"vertex_ai": 0.05} = 5% discount
#     556 cost_margin_config: Dict[str, Union[float, Dict[str, float]]] = (
#     557     {}
#     558 )  # Provider-specific or global cost margins. Examples:
#
# ...

# %% [markdown]
# ### Load API Keys

# %% [markdown]
# - https://platform.claude.com
# - https://aistudio.google.com
# - https://platform.openai.com
# - https://platform.deepseek.com

# %%
load_dotenv() # Loads your API keys from a .env file
# Out:
# True

# %% [markdown]
# ### Use LiteLLM

# %%
# anthropic/claude-haiku-4-5
anthropic_response = completion(model="anthropic/claude-haiku-4-5", messages=[{"role": "user", "content": "Write a haiku about soccer!"}])

# openai/gpt-4o-mini
openai_response = completion(model="openai/gpt-4o-mini", messages=[{"role": "user", "content": "Write a haiku about soccer!"}])

# gemini/gemini-3.6-flash
gemini_response = completion(model="gemini/gemini-3.6-flash", messages=[{"role": "user", "content": "Write a haiku about soccer!"}])

# deepseek/deepseek-v4-flash
deepseek_response = completion(model="deepseek/deepseek-v4-flash", messages=[{"role": "user", "content": "Write a haiku about soccer!"}])

# %%
print("Anthropic response:")
print(anthropic_response.choices[0].message.content)
print('------------------------------------')

print("OpenAI response:")
print(openai_response.choices[0].message.content)

print('------------------------------------')
print("Gemini response:")
print(gemini_response.choices[0].message.content)

print('------------------------------------')
print("DeepSeek response:")
print(deepseek_response.choices[0].message.content)
# Out:
# Anthropic response:
# # Soccer Haiku
#
# Swift feet on the grass
# Ball curves past the outstretched hands—
# Net ripples with joy
# ------------------------------------
# OpenAI response:
# Grass beneath our feet,
# A whistle breaks the still air,
# Goals ignite the crowd.
# ------------------------------------
# Gemini response:
# Green grass, flying ball,
# One sharp kick toward the net,
# The stadium roars.
# ------------------------------------
# DeepSeek response:
# A sudden swift kick,
# The ball arcs past the goalie—
# Silence, then the roar.

# %% [markdown]
# ### How it works

# %% [markdown]
# LiteLLM acts as a translator between your application and the model provider.

# %% [markdown]
# #### Anthropic Models

# %%
anthropic_response = completion(
    model="claude-haiku-4-5",
    messages=[
        {
              "role": "user",
              "content": "Write a haiku about soccer!"
        }
      ]
  )

# %%
import anthropic

client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

response = client.messages.create(
    model="claude-haiku-4-5",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": "Write a haiku about soccer!"
        }
    ]
)

# %% [markdown]
# #### OpenAI Models

# %%
open_ai_response = completion(
    model="openai/gpt-4o-mini",
    messages=[
        {
              "role": "user",
              "content": "Write a haiku about soccer!"
        }
      ]
  )

# %%
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "Write a haiku about soccer!"
        }
    ]
)

# %% [markdown]
# ### Documents

# %% [markdown]
# - GitHub - https://github.com/BerriAI/litellm
# - Getting Started - https://docs.litellm.ai/
# - Model Catalog - https://models.litellm.ai/
